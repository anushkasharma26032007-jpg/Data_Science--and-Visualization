# %%
print("Hello World")
# Out:
# Hello World

# %%
print(10)
print("Anushka")
print(10+20)
# Out:
# 10
# Anushka
# 30

# %%
print("10+20")
# Out:
# 10+20

# %%
print(input("Nmae: "))
print(input("age: "))
print(25+35)
print(input("ye : "))
# Out:
# Nmae: Anushka Sharma
# Anushka Sharma
# age: 20
# 20
# 60
# ye : I am learing python
# I am learing python

# %%
name = "Anushka"
print(name)
# Out:
# Anushka

# %%
name = "my name is "
print(input("My  name is "))
print(input("My age is :"a ))
# Out:
# My  name is Anushka sharm
# Anushka sharm
# My age is :20
# 20

# %%
student =  True;
print(type(student))
# Out:
# <class 'bool'>

# %%
name =input("Enter Your  name :")
age = input("Enter Your  age :")
# Out:
# Enter Your  name :Anu
# Enter Your  age :22
